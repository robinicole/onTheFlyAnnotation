# %%
# %load_ext autoreload
# %autoreload 2
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))
import pandas as pd
from smart_annotator import DataToClassifyStd

# %%
import requests
import json


articles = requests.get('https://itemstore-v2-stag.inyourarea.co.uk/items/articles?count=3000', headers={'Authorization': 'Bearer D559B9F06455FD90709CABFC1C6CF7BC2D0E29A8'}).json()
articles_df = pd.DataFrame([{"body": article['item']['body'], "title": article['item']['title']} for article in articles])
articles_df.to_csv('../data/articles_to_classify.csv')

# %%
to_cl = DataToClassifyStd(articles_df.title.values)

# %%
to_cl.df.loc[38]
# Out:
# {'X': 'How to get tickets for Reading and Leeds Festival 2021 - and everything you need to know | Halifax Courier',
#  'y': 1,
#  'score': None,
#  'process_data': [0.005263211403843518,
#   0.00526324972990043,
#   0.00526330876681972,
#   0.005263367062824852,
#   0.005263265154842959,
#   0.06263415304685009,
#   0.8952595892882259,
#   0.005263296614622946,
#   0.0052632654986153465,
#   0.005263293433454124]}

# %%
to_cl.print_data()
# Out:
# Index: 827
# The politics column: MP Trudy Harrison on the best ways to fight the virus
#
#
# Index: 106
# Bay Area officials approve plan that requires employees to work from home three days a week
#
#
# Index: 389
# Parents of gambling addict from Sheffield who took his own life aged 24 say state 'does not want to know what killed perfectly healthy and happy' son
#
#
# Index: 201
# No more Coronavirus deaths today in Bradford hospitals
#
#
# Index: 744
# Wrexham residents warned of 'Netflix' email scam
#
#
# Index: 713
# 'Why did Stonehaven flood again?' Campaigners accuse agencies of 'hiding behind Covid' over flash flooding - Evening Express
#
#
# Index: 799
# 15 North London dogging hotspots which are hidden in plain sight from public
#
#
# Index: 774
# CORONAVIRUS: 11 new cases confirmed in East Devon
#
#
# Index: 358
# CORONAVIRUS: No new deaths in Worcestershire's hospitals
#
#
# Index: 264
# Hertford Bircherley Green: Premier Inn withdraws plans for 86-bedroom hotel
#
#
# ...

# %%
labeled = to_cl.df[to_cl.df.y == 1].index
labeled
# Out:
# Int64Index([29, 42, 278, 595], dtype='int64')

# %%
to_cl.df.iloc[[39, 1511, 2074, 2255, 3981, 6953, 7312, 7435, 8314, 8631, 8742, 9959]].process_data.apply(len)
# Out:
# 39      10
# 1511    10
# 2074    10
# 2255    10
# 3981    10
# 6953    10
# 7312    10
# 7435    10
# 8314    10
# 8631    10
# 8742    10
# 9959    10
# Name: process_data, dtype: int64
